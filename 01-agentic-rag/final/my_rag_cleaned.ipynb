# %%
from my_rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.'

# %%
print(assistant.rag('How to run Ollama?'))
# Out:
# Run Ollama by opening a terminal and typing:
#
# ```bash
# ollama run llama3
# ```
#
# This will download the model and start a local chat interface.
#
# If you want to test that the Ollama server is running, you can also check:
#
# ```bash
# curl http://localhost:11434
# ```
#
# If you get a connection refused error, restart the server with:
#
# ```bash
# !nohup ollama serve > nohup.out 2>&1 &
# ```
